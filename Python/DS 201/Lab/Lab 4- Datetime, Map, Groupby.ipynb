# %% [markdown]
# # This Lab is open from 6 am  9/27-3:30 pm on Friday

# %% [markdown]
# ### Lab 4 Ben Porter

# %% [markdown]
# This labk explores frequency table, creating new dataframes and some other data analysis tools in pandas using mostly groupby function in pandas. Read more about groupby, map and datetime in the following links.
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_datetime.html
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.map.html
#
# We will be using a csv data set called climbing_statistics. This data set contains Mount Rainer climbing statistics in the year 2015. It has 5 columns.
#
# Date: Day of the record
#
# Route: The route used to climb the Mt Rainier
#
# Attempted: Number of people who attempted the climb
#
# Succeeded: Number of people who succeeded in reaching the summit
#
# Success Percentage: Percentage of people who succeeded in reaching the summit.
#
# More details about this data set is here. https://www.kaggle.com/codersree/mount-rainier-weather-and-climbing-data#climbing_statistics.csv. Before starting this homework, please follow this link and read more about this data set. Also make sure to save it in the same folder as your Lab 4 solutions inside DS 201 main folder.

# %% [markdown]
# Please import appropriate libraries as usual and load the data.

# %%
import pandas as pd
import numpy as np
import matplotlib as mpt
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('climbing_statistics.csv')
df['Date'] = pd.to_datetime(df['Date'])# This is to make sure that Date column 
#is in pandas datetime format.

# %% [markdown]
# ### Problem 1
# Make a frequency table of the variable "Attempted" by month. Code hint is given to you below. Explain each piece of the code by googling. You need to explain how each piece in the following code helped calculate the frequency table from the original data. Change the column name "Date" to "Month" and "Attempted" to "Attempted_count. ( 14 points)

# %%
df.rename(columns={'Date':'Month'}, inplace=True)
df.rename(columns={'Attempted':'Attempted_count'}, inplace=True)

# %%
#Hint: df.groupby(df['Date'].dt.strftime('%B'))['Attempted'].sum().to_frame().reset_index()
df.groupby(df['Month'].dt.strftime('%B'))['Attempted_count'].sum().to_frame().reset_index()
# Out:
#         Month  Attempted_count
# 0       April              273
# 1      August             4310
# 2    December                3
# 3    February               84
# 4     January              106
# 5        July             6479
# 6        June             5606
# 7       March              157
# 8         May             2128
# 9    November                7
# 10    October               32
# 11  September             1768

# %% [markdown]
# ### Problem 2
# Give a new name to the data frame in Problem 1. Make a scatter plot of the data with month in x-axis and attempted count in y axis. Explain what this plot is telling you in a few sentences. ( 12 points)

# %%
df2=df
# Please do the following before plotting.
#1. Create a dictionary of Month and month numbers
d = {'January':1, 'February':2, 'March':3, 'April':4, 'May':5, 'June':6, 'July':7, 'August':8, 'September':9, 'October':10, 'November':11, 'December':12}
# 2. Change the Month names to numbers with the following code.
df2.Month = df2.Month.map(d)
# 3. Sort Month column by using
df2.sort_values('Month')
#The reason we are doing this is to make our plot look better. Month name will be crowded.
# Out:
#       Month                   Route  Attempted_count  Succeeded  \
# 0       NaN  Disappointment Cleaver                2          0
# 1       NaN  Disappointment Cleaver                3          0
# 2       NaN  Disappointment Cleaver                2          0
# 3       NaN           Little Tahoma                8          0
# 4       NaN  Disappointment Cleaver                2          0
# 5       NaN  Disappointment Cleaver               10          0
# 6       NaN  Disappointment Cleaver                2          0
# 7       NaN           Kautz Glacier                2          0
# 8       NaN  Disappointment Cleaver                2          0
# 9       NaN  Disappointment Cleaver                2          0
# 10      NaN  Disappointment Cleaver               12          4
# 11      NaN  Disappointment Cleaver               12          6
# 12      NaN  Disappointment Cleaver                2          0
# 13      NaN  Disappointment Cleaver               12          3
# 14      NaN  Disappointment Cleaver                3          0
# 15      NaN  Disappointment Cleaver               12          9
# 16      NaN  Disappointment Cleaver               11          6
# 17      NaN  Disappointment Cleaver               10          0
# 18      NaN  Disappointment Cleaver               11          1
# 19      NaN  Disappointment Cleaver               12          0
# 20      NaN  Disappointment Cleaver                3          0
# 21      NaN  Disappointment Cleaver                2          0
# 22      NaN  Disappointment Cleaver                2          0
# 23      NaN  Disappointment Cleaver               11          0
# 24      NaN  Disappointment Cleaver                8          0
# 25      NaN  Disappointment Cleaver               10          9
# 26      NaN  Disappointment Cleaver                3          0
# 27      NaN  Disappointment Cleaver               12          7
# 28      NaN  Disappointment Cleaver               12          0
# 29      NaN  Disappointment Cleaver               11          0
# ...     ...                     ...              ...        ...
# 4047    NaN  Disappointment Cleaver                8          6
# 4048    NaN  Disappointment Cleaver                2          0
# 4049    NaN  Disappointment Cleaver                5          0
# 4050    NaN  Disappointment Cleaver                8          0
# 4051    NaN  Disappointment Cleaver                8          0
# 4052    NaN        Gibralter Ledges                3          0
# 4053    NaN         Ingraham Direct                2          0
# 4054    NaN        Gibralter Ledges                2          2
# 4055    NaN         Ingraham Direct                4          0
# 4056    NaN        Gibralter Ledges                2          0
# 4057    NaN        Gibralter Ledges                2          0
# 4058    NaN         Ingraham Direct                4          0
# 4059    NaN         Ingraham Direct                2          2
# 4060    NaN         Ingraham Direct                2          0
# 4061    NaN        Gibralter Ledges                2          2
# 4062    NaN        Gibralter Ledges                1          0
# 4063    NaN        Gibralter Ledges                2          2
# 4064    NaN        Gibralter Ledges                2          2
# 4065    NaN        Gibralter Ledges                2          0
# 4066    NaN           Little Tahoma                2          0
# 4067    NaN         Fuhrer's Finger                2          0
# 4068    NaN        Gibralter Ledges                2          0
# 4069    NaN        Gibralter Ledges                2          0
# 4070    NaN        Gibralter Ledges                4          4
# 4071    NaN        Gibralter Ledges                2          0
# 4072    NaN           Little Tahoma                2          0
# 4073    NaN  Disappointment Cleaver                8          0
# 4074    NaN  Disappointment Cleaver                8          0
# 4075    NaN  Disappointment Cleaver                2          0
# 4076    NaN        Gibralter Ledges                3          2
#
#       Success Percentage
# 0               0.000000
# 1               0.000000
# 2               0.000000
# 3               0.000000
# 4               0.000000
# 5               0.000000
# 6               0.000000
# 7               0.000000
# 8               0.000000
# 9               0.000000
# 10              0.333333
# 11              0.500000
# 12              0.000000
# 13              0.250000
# 14              0.000000
# 15              0.750000
# 16              0.545455
# 17              0.000000
# 18              0.090909
# 19              0.000000
# 20              0.000000
# 21              0.000000
# 22              0.000000
# 23              0.000000
# 24              0.000000
# 25              0.900000
# 26              0.000000
# 27              0.583333
# 28              0.000000
# 29              0.000000
# ...                  ...
# 4047            0.750000
# 4048            0.000000
# 4049            0.000000
# 4050            0.000000
# 4051            0.000000
# 4052            0.000000
# 4053            0.000000
# 4054            1.000000
# 4055            0.000000
# 4056            0.000000
# 4057            0.000000
# 4058            0.000000
# 4059            1.000000
# 4060            0.000000
# 4061            1.000000
# 4062            0.000000
# 4063            1.000000
# 4064            1.000000
# 4065            0.000000
# 4066            0.000000
# 4067            0.000000
# 4068            0.000000
# 4069            0.000000
# 4070            1.000000
# 4071            0.000000
# 4072            0.000000
# 4073            0.000000
# 4074            0.000000
# 4075            0.000000
# 4076            0.666667
#
# [4077 rows x 5 columns]

# %% [markdown]
# ### Each time I run this code the months show up as NaN and no matter what I do it stays this way and I cannot figure out how to remedy this situation.

# %%
plt.plot(df2.Month, df2.Attempted_count)
plt.title('Attempts Per Month')
plt.ylabel('Attempted_count');
plt.xlabel('Month');
plt.show()

# %% [markdown]
# This plot tells you how many attempts there were each month.

# %% [markdown]
# #### Problem 3
# Use the code yourdf.groupby(yourdf['Route']).sum().reset_index() to make a new data frame. This data frame adds all the attempted, succeeded and success percentage for each route irrespective of the date. Display the data and you will see that the success percentage column is not quite right. The first entry has 4 attempted, 2 succeeded which is 50\% success rate but the success percentage column says 1\%. Likewise, there are now numbers which are more than 100 in this column. Succeeded number is never more than attempted sothe success percentage is never more than 100\%. Create a new column called Success Rate that has correct values for the success rate. Drop the Success Percentage column and give this data frame a new name. (14 points)

# %%
df2.groupby(df2['Route']).sum().reset_index()
# Out:
#                                Route  Month  Attempted_count  Succeeded  \
# 0          Curtis RIngraham Directge    0.0                4          2
# 1             Disappointment Cleaver    0.0            15259       8353
# 2                         Edmonds HW    0.0                4          0
# 3                    Emmons-Winthrop    0.0             3048       1673
# 4                    Fuhrer's Finger    0.0              197         79
# 5                     Fuhrers Finger    0.0               76          9
# 6                    Gibralter Chute    0.0               13          2
# 7                   Gibralter Ledges    0.0              199         58
# 8                    Ingraham Direct    0.0              225         16
# 9                      Kautz Cleaver    0.0               51         16
# 10                     Kautz Glacier    0.0              949        530
# 11                    Kautz Headwall    0.0                3          0
# 12        Liberty RIngraham Directge    0.0              165         82
# 13                      Liberty Wall    0.0                2          0
# 14                     Little Tahoma    0.0              296        135
# 15                       Mowich Face    0.0                8          2
# 16                 Nisqually Glacier    0.0               14          0
# 17      Ptarmigan RIngraham Directge    0.0               57         29
# 18                   Success Cleaver    0.0               16          7
# 19               Sunset Amphitheater    0.0                2          0
# 20         Sunset RIngraham Directge    0.0                6          0
# 21                    Tahoma Cleaver    0.0                3          3
# 22                    Tahoma Glacier    0.0               33         11
# 23                           Unknown    0.0              131         30
# 24                   Wilson Headwall    0.0                5          0
# 25  glacier only - no summit attempt    0.0              187         15
#
#     Success Percentage
# 0             1.000000
# 1          1438.553283
# 2             0.000000
# 3           338.216739
# 4            24.166667
# 5             3.000000
# 6             1.000000
# 7            20.500000
# 8             7.000000
# 9             3.666667
# 10           96.453535
# 11            0.000000
# 12           36.000000
# 13            0.000000
# 14           33.091667
# 15            1.000000
# 16            0.000000
# 17           11.666667
# 18            3.000000
# 19            0.000000
# 20            0.000000
# 21            1.000000
# 22            4.666667
# 23            7.436364
# 24            0.000000
# 25            3.000000

# %%
del df2['Success Percentage']

# %%
S = df2['Succeeded']
A = df2['Attempted_count']
df2['Success Rate'] =S/A*100
df3=df2
print (df3)
# Out:
#       Month                   Route  Attempted_count  Succeeded  Success Rate
# 0       NaN  Disappointment Cleaver                2          0      0.000000
# 1       NaN  Disappointment Cleaver                3          0      0.000000
# 2       NaN  Disappointment Cleaver                2          0      0.000000
# 3       NaN           Little Tahoma                8          0      0.000000
# 4       NaN  Disappointment Cleaver                2          0      0.000000
# 5       NaN  Disappointment Cleaver               10          0      0.000000
# 6       NaN  Disappointment Cleaver                2          0      0.000000
# 7       NaN           Kautz Glacier                2          0      0.000000
# 8       NaN  Disappointment Cleaver                2          0      0.000000
# 9       NaN  Disappointment Cleaver                2          0      0.000000
# 10      NaN  Disappointment Cleaver               12          4     33.333333
# 11      NaN  Disappointment Cleaver               12          6     50.000000
# 12      NaN  Disappointment Cleaver                2          0      0.000000
# 13      NaN  Disappointment Cleaver               12          3     25.000000
# 14      NaN  Disappointment Cleaver                3          0      0.000000
# 15      NaN  Disappointment Cleaver               12          9     75.000000
# 16      NaN  Disappointment Cleaver               11          6     54.545455
# 17      NaN  Disappointment Cleaver               10          0      0.000000
# 18      NaN  Disappointment Cleaver               11          1      9.090909
# 19      NaN  Disappointment Cleaver               12          0      0.000000
# 20      NaN  Disappointment Cleaver                3          0      0.000000
# 21      NaN  Disappointment Cleaver                2          0      0.000000
# 22      NaN  Disappointment Cleaver                2          0      0.000000
# 23      NaN  Disappointment Cleaver               11          0      0.000000
# 24      NaN  Disappointment Cleaver                8          0      0.000000
# 25      NaN  Disappointment Cleaver               10          9     90.000000
# 26      NaN  Disappointment Cleaver                3          0      0.000000
# 27      NaN  Disappointment Cleaver               12          7     58.333333
# 28      NaN  Disappointment Cleaver               12          0      0.000000
# 29      NaN  Disappointment Cleaver               11          0      0.000000
# ...     ...                     ...              ...        ...           ...
# 4047    NaN  Disappointment Cleaver                8          6     75.000000
# 4048    NaN  Disappointment Cleaver                2          0      0.000000
# 4049    NaN  Disappointment Cleaver                5          0      0.000000
# 4050    NaN  Disappointment Cleaver                8          0      0.000000
# 4051    NaN  Disappointment Cleaver                8          0      0.000000
# 4052    NaN        Gibralter Ledges                3          0      0.000000
# 4053    NaN         Ingraham Direct                2          0      0.000000
# 4054    NaN        Gibralter Ledges                2          2    100.000000
# 4055    NaN         Ingraham Direct                4          0      0.000000
# 4056    NaN        Gibralter Ledges                2          0      0.000000
# 4057    NaN        Gibralter Ledges                2          0      0.000000
# 4058    NaN         Ingraham Direct                4          0      0.000000
# 4059    NaN         Ingraham Direct                2          2    100.000000
# 4060    NaN         Ingraham Direct                2          0      0.000000
# 4061    NaN        Gibralter Ledges                2          2    100.000000
# 4062    NaN        Gibralter Ledges                1          0      0.000000
# 4063    NaN        Gibralter Ledges                2          2    100.000000
# 4064    NaN        Gibralter Ledges                2          2    100.000000
# 4065    NaN        Gibralter Ledges                2          0      0.000000
# 4066    NaN           Little Tahoma                2          0      0.000000
# 4067    NaN         Fuhrer's Finger                2          0      0.000000
# 4068    NaN        Gibralter Ledges                2          0      0.000000
# 4069    NaN        Gibralter Ledges                2          0      0.000000
# 4070    NaN        Gibralter Ledges                4          4    100.000000
# 4071    NaN        Gibralter Ledges                2          0      0.000000
# 4072    NaN           Little Tahoma                2          0      0.000000
# 4073    NaN  Disappointment Cleaver                8          0      0.000000
# 4074    NaN  Disappointment Cleaver                8          0      0.000000
# 4075    NaN  Disappointment Cleaver                2          0      0.000000
# 4076    NaN        Gibralter Ledges                3          2     66.666667
#
# [4077 rows x 5 columns]

# %% [markdown]
# I created a new column named Success Rate where the Succeeded was divided by the Attempted_count and then multiplied by 100 in order to get a percentage.

# %% [markdown]
# ##### Problem 4
# Sort the newly created column Success Rate in Problem 3 and list 5 routes with highest success rates and 5 routes with lowest success rates. ( 8 points)

# %%
df3=df.sort_values(by=['Success Rate'], ascending=False)
df3.head()
# Out:
#       Month                   Route  Attempted_count  Succeeded  Success Rate
# 589     NaN  Disappointment Cleaver                5         71   1420.000000
# 1156    NaN  Disappointment Cleaver                2          5    250.000000
# 191     NaN  Disappointment Cleaver                1          2    200.000000
# 3196    NaN  Disappointment Cleaver                1          2    200.000000
# 507     NaN         Emmons-Winthrop                3          4    133.333333

# %%
df3=df.sort_values(by=['Success Rate'], ascending=True)
df3.head()
# Out:
#       Month                   Route  Attempted_count  Succeeded  Success Rate
# 0       NaN  Disappointment Cleaver                2          0           0.0
# 1391    NaN  Disappointment Cleaver                3          0           0.0
# 1390    NaN           Kautz Glacier                2          0           0.0
# 2813    NaN  Disappointment Cleaver                3          0           0.0
# 1388    NaN  Disappointment Cleaver                2          0           0.0

# %% [markdown]
# For some reason in the dataframe there is some incorrect data that says the number of succeeded attempts is larger than the number of attempts so when you find the highest success rates you get percentages larger than 100.

# %%
35/10.0
# Out:
# 3.5

# %%
3**3
# Out:
# 27
